# %% [markdown]
# # Création d'une table globale de puissance dispo temporelle

# %%
import pandas as pd

# %%
plants = pd.read_csv('./database_plants.csv', sep = ';', encoding = "ISO-8859-1")

# %%
plants
# Out:
#   Wind farm name Total nominal power         Latitude        Longitude
# 0        AinaÅ¾i              600 kW    57Â° 52' 7.1"   24Â° 22' 30.9"
# 1        Arsenal              850 kW      56Â° 21' 9"      21Â° 6' 17"
# 2    Baltnorvent            2,000 kW   56Â° 58' 12.2"   21Â° 40' 41.1"
# 3     BK Energia            2,000 kW   56Â° 31' 49.8"       21Â° 6' 0"
# 4   Enercom Plus            2,700 kW   57Â° 23' 56.2"    21Â° 51' 4.9"
# 5         Impakt            1,000 kW   57Â° 14' 58.2"   21Â° 28' 12.1"
# 6        Liepaja            2,000 kW   56Â° 42' 17.5"    21Â° 5' 32.5"
# 7           Pope           20,700 kW   57Â° 23' 56.2"    21Â° 51' 4.9"
# 8         Seteri              850 kW      56Â° 21' 9"      21Â° 6' 17"
# 9     Veju parks           19,800 kW   56Â° 32' 16.7"     21Â° 14' 31"

# %%
plant1 = pd.read_csv('./ninja_pv_Pope.csv', header=[1,2])

# %%
plant1
# Out:
#                   time        local_time    output
#                    UTC      Europe/Paris        kW
# 0     2016-01-01 00:00  2016-01-01 01:00     0.000
# 1     2016-01-01 01:00  2016-01-01 02:00     0.000
# 2     2016-01-01 02:00  2016-01-01 03:00     0.000
# 3     2016-01-01 03:00  2016-01-01 04:00     0.000
# 4     2016-01-01 04:00  2016-01-01 05:00     0.000
# 5     2016-01-01 05:00  2016-01-01 06:00     0.000
# 6     2016-01-01 06:00  2016-01-01 07:00     0.000
# 7     2016-01-01 07:00  2016-01-01 08:00     0.000
# 8     2016-01-01 08:00  2016-01-01 09:00   209.498
# 9     2016-01-01 09:00  2016-01-01 10:00   606.501
# 10    2016-01-01 10:00  2016-01-01 11:00  1077.800
# 11    2016-01-01 11:00  2016-01-01 12:00  1507.580
# 12    2016-01-01 12:00  2016-01-01 13:00  1518.027
# 13    2016-01-01 13:00  2016-01-01 14:00   899.316
# 14    2016-01-01 14:00  2016-01-01 15:00   452.686
# 15    2016-01-01 15:00  2016-01-01 16:00   107.341
# ...

# %%
prod = pd.DataFrame(index = plants['Wind farm name',columns = range(1,8784))
# Out:
#   File "<ipython-input-21-7f90ed97db5d>", line 1
#     prod = pd.DataFrame(index = plants['Wind farm name',columns = range(1,8784))
#                                                                 ^
# SyntaxError: invalid syntax
